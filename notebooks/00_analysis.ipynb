# %%
#!pip install music21
from music21 import *

# %%
file = converter.parse('../data/raw/bonjovi.mid')
file.show('midi')
# Out:
#                 <div id='midiPlayerDiv188639'></div>
#                 <link rel="stylesheet" href="//cuthbertLab.github.io/music21j/css/m21.css"
#                     type="text/css" />
#                 <script>
#                 require.config({
#                     paths: {'music21': '//cuthbertLab.github.io/music21j/src/music21'}
#                 });
#                 require(['music21'], function() {
#                                mp = new music21.miditools.MidiPlayer();
#                                mp.addPlayer('#midiPlayerDiv188639');
#                                mp.base64Load('data:audio/midi;base64,...');
#                         });
#                 </script>

# %%
file.show("text")
# Out:
# {0.0} <music21.stream.Part 0x10eb93c18>
#     {0.0} <music21.instrument.Instrument >
#     {0.0} <music21.instrument.Instrument >
#     {0.0} <music21.tempo.MetronomeMark allegro moderato Quarter=128.0>
#     {0.0} <music21.meter.TimeSignature 4/4>
#     {0.0} <music21.stream.Voice 0x10eb8d2e8>
#         {0.0} <music21.note.Rest rest>
#         {38.5} <music21.note.Note D>
#         {39.0} <music21.note.Note E>
#         {39.5} <music21.note.Note E>
#         {40.0} <music21.note.Note E>
#         {40.5} <music21.note.Note D>
#         {41.0} <music21.note.Note E>
#         {41.5} <music21.note.Note E>
#         {42.0} <music21.note.Note B>
#         {42.5} <music21.note.Note D>
#         {43.0} <music21.note.Note E>
#         {43.5} <music21.note.Note E>
#         {44.0} <music21.note.Note E>
#         {44.5} <music21.note.Note D>
#         {45.0} <music21.note.Note E>
#         {45.5} <music21.note.Note E>
#         {46.0} <music21.note.Note B>
# ...

# %%
file.plot('pianoroll')

# %%
components = []
for element in file.recurse():
    components.append(element)

# %%
components
# Out:
# [<music21.stream.Score 0x11a377f98>,
#  <music21.stream.Part 0x11a156400>,
#  <music21.instrument.Instrument >,
#  <music21.tempo.MetronomeMark animato Quarter=120.0>,
#  <music21.key.Key of C major>,
#  <music21.meter.TimeSignature 4/4>,
#  <music21.note.Note E>,
#  <music21.note.Rest rest>,
#  <music21.note.Note D>,
#  <music21.note.Rest rest>,
#  <music21.note.Note A>,
#  <music21.note.Rest rest>,
#  <music21.note.Note A>,
#  <music21.note.Rest rest>,
#  <music21.note.Note A>,
#  <music21.note.Note A>,
#  <music21.note.Note E>,
#  <music21.note.Rest rest>,
#  <music21.note.Note D>,
#  <music21.note.Rest rest>,
#  <music21.note.Note A>,
#  <music21.note.Rest rest>,
#  <music21.note.Note A>,
#  <music21.note.Rest rest>,
#  <music21.note.Note A>,
#  <music21.note.Note A>,
#  <music21.note.Note E>,
#  <music21.note.Rest rest>,
#  <music21.note.Note D>,
#  <music21.note.Rest rest>,
#  <music21.note.Note A>,
#  <music21.note.Rest rest>,
#  <music21.note.Note A>,
# ...
